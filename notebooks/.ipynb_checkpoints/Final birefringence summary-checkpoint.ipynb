# %%
import os,sys
sys.path.append(os.path.abspath("../"))
import healpy as h
import collections
from modules.calc_EB_rec_noise.fast_calc_eb_rec_noise import calc_eb_rec_noise
from modules.calc_TB_rec_noise.fast_calc_tb_rec_noise import calc_tb_rec_noise
from modules import eb_rec
from modules import tb_rec
import pandas as pd
import dataframe_image as dfi

from astropy.io import fits
figpath="../results/final_bire/"

def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
ensure_dir(figpath)

datapath=figpath + "/final_bire/" ; ensure_dir(datapath)

def return_Nl(fwhm,noise_rms,lmax):
    ell=np.arange(lmax+1)
    noise_rms=noise_rms*(1./60.)*(np.pi/180.)
    thetab=((fwhm/60.)*np.pi/180.)/np.sqrt(8.*np.log(2))
    Bl=exp(thetab**2 *(ell*(ell+1))/2)
    return ell,noise_rms**2. * Bl**2.

# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/envs/hp/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Analysis settings

# %%
nside=1024
lmax_list=[768,1024,1536]
lpad=256
lmin=2
lmax=max(lmax_list)
Lmax=512

clthry=np.loadtxt("../planck_cmb_cl/COM_PowerSpect_CMB-base-plikHM-TTTEEE-lowl-lowE-lensing-minimum-theory_R3.01.txt")

maxell=2048
ell=clthry[:maxell+1,0] ; fl=ell*(ell+1)/(2.*pi)
cltt=clthry[:maxell+1,1]/fl ; cltt=append([0.,0.],cltt)
clte=clthry[:maxell+1,2]/fl ; clte=append([0.,0.],clte)
clee=clthry[:maxell+1,3]/fl ; clee=append([0.,0.],clee)
clbb=clthry[:maxell+1,4]/fl ; clbb=append([0.,0.],clbb)
ell=append([0.,1,],ell) ; fl=ell*(ell+1)/(2.*pi)
clthr=[cltt,clee,clbb,clte]

fname_143="/Users/adityarotti/Documents/Work/Data/Planck/maps/HFI_SkyMap_143-field-IQU_2048_R3.00_full.fits"
fname_smica="/Users/adityarotti/Documents/Work/Data/Planck/maps/COM_CMB_IQU-smica_2048_R3.00_full.fits"

#RIMO beams
rimobeam="/Users/adityarotti/Documents/Work/Data/Planck/maps/HFI_RIMO_Beams-075pc_R2.00.fits"

# Mask names
#Common mask apodized
apomaskname="/Users/adityarotti/Documents/Work/Data/Planck/masks/HFI_Mask_GalPlane-apo2_2048_R2.00.fits"
#Common mask sharp
commaskname="/Users/adityarotti/Documents/Work/Data/Planck/masks/HFI_Mask_GalPlane-apo0_2048_R2.00.fits"
#Common polarization mask sharp
polmaskname=maskname="/Users/adityarotti/Documents/Work/Data/Planck/masks/COM_Mask_CMB-common-Mask-Pol_2048_R3.00.fits"

# %% [markdown]
# # Masks

# %%
mask_list=["mask78","mask72","mask62","mask52"]
masks={}
masks["mask78"]=h.ud_grade(h.read_map(polmaskname,dtype=np.float64,verbose=False),nside)
masks["mask72"]=h.ud_grade(h.read_map(commaskname,4,dtype=np.float64,verbose=False),nside)
masks["mask62"]=h.ud_grade(h.read_map(commaskname,3,dtype=np.float64,verbose=False),nside)
masks["mask52"]=h.ud_grade(h.read_map(commaskname,2,dtype=np.float64,verbose=False),nside)
# Out:
# /opt/anaconda3/envs/hp/lib/python3.7/site-packages/healpy/fitsfunc.py:369: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# /opt/anaconda3/envs/hp/lib/python3.7/site-packages/healpy/fitsfunc.py:426: UserWarning: No INDXSCHM keyword in header file : assume IMPLICIT
#   warnings.warn("No INDXSCHM keyword in header file : " "assume {}".format(schm))

# %% [markdown]
# # Beams

# %%
beam={}
f=fits.open(rimobeam)
beam["143 Ghz"]=f[4].data[0][0][:lmax+lpad+1]
f.close()

f=fits.open(fname_smica)
beam["SMICA"]=f[2].data.field(0)[:lmax+lpad+1]
f.close()

# %% [markdown]
# # Beam deconvolved data

# %%
def return_deconvolved_data(fname,bl,nside):
    tqu=h.read_map(fname,(0,1,2),dtype=np.float64,verbose=False)*1e6
    alm=h.map2alm(tqu,lmax=lmax+lpad)
    invbl=np.ones_like(bl) ; invbl[2:]=1./bl[2:]
    alm[0]=h.almxfl(alm[0],fl=invbl)
    alm[1]=h.almxfl(alm[1],fl=invbl)
    alm[2]=h.almxfl(alm[2],fl=invbl)
    dec_tqu=h.alm2map(alm,pol=True,nside=nside)
    return dec_tqu
    
data={}
data["SMICA"]=return_deconvolved_data(fname_smica,beam["SMICA"],nside)
data["143 GHz"]=return_deconvolved_data(fname_143,beam["143 Ghz"],nside)

# %%
lmax_list=[768,1024,1536]

result=collections.OrderedDict()

for x in data.keys():
    result[x]=collections.OrderedDict()
    for msk in masks.keys():
        result[x][msk]=collections.OrderedDict()
        for lmax in lmax_list:
            print(x,msk,lmax)
            result[x][msk][lmax]=collections.OrderedDict()
            eb=eb_rec.opt_eb_qe(data[x],clthr,lmax,Lmax,mask=masks[msk],ellmin=lmin)
            eb.eb_reconstruct()
            result[x][msk][lmax]["CL"]=np.copy(eb.Cl_rec_alpha)
            result[x][msk][lmax]["NL"]=np.copy(eb.N_L)
            result[x][msk][lmax]["fsky"]=np.copy(eb.fsky)
# Out:
# SMICA mask78 768
# SMICA mask78 1024
# SMICA mask78 1536
# SMICA mask72 768
# SMICA mask72 1024
# SMICA mask72 1536
# SMICA mask62 768
# SMICA mask62 1024
# SMICA mask62 1536
# SMICA mask52 768
# SMICA mask52 1024
# SMICA mask52 1536
# 143 GHz mask78 768
# 143 GHz mask78 1024
# 143 GHz mask78 1536
# 143 GHz mask72 768
# 143 GHz mask72 1024
# 143 GHz mask72 1536
# 143 GHz mask62 768
# 143 GHz mask62 1024
# 143 GHz mask62 1536
# 143 GHz mask52 768
# 143 GHz mask52 1024
# 143 GHz mask52 1536

# %%
k="SMICA"
msk="mask52"
lmax=1024
figure()
plot(result[k][msk][lmax]["CL"])
plot(result[k][msk][lmax]["NL"])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Gaussian Likelihood

# %%
def calc_u95(Clobs,Nl,fsky,Lmax,Arng=[-5.5,-3],sampling=500):
    from scipy.integrate import romberg
    from scipy.interpolate import interp1d
    Avals=np.logspace(Arng[0],Arng[1],sampling)
    L=arange(Lmax+1)
    clthry=np.ones_like(L) ; clthry[1:]=2.*np.pi/(L[1:]*(L[1:]+1.))
    Avals=np.logspace(Arng[0],Arng[1],sampling)
    Avals=np.append(0,Avals)
    chi2=np.zeros_like(Avals)
    for i,A in enumerate(Avals):
        chi2[i]=bire_lkl(A,Clobs,Nl,clthry,fsky,Lmax)
    
    chi2=chi2/min(chi2)
    fnpdf=interp1d(Avals,np.exp(-chi2),kind="cubic",fill_value="extrapolate")
    norm=romberg(fnpdf,min(Avals),max(Avals))
    fnpdf=interp1d(Avals,np.exp(-chi2)/norm,kind="cubic",fill_value="extrapolate")
    cpdf=np.zeros_like(Avals[2:])
    for i,A in enumerate(Avals[2:]):
        cpdf[i]=quad(fnpdf,min(Avals),A)[0]

    fncpdf=interp1d(cpdf,Avals[2:],kind="cubic",fill_value="extrapolate")
    return fncpdf(0.95)

def bire_lkl(A,Clobs,Nl,clthry,fsky,Lmax):
    L=np.arange(Lmax+1)
    var=(2./((2.*L+1)*fsky))*Nl[:Lmax+1]**2.
    chi2=np.sum((Clobs[1:Lmax]-Nl[1:Lmax]-A*clthry[1:Lmax])**2/var[1:Lmax])
    return chi2

# %%
stat=collections.OrderedDict()
stat["mask"]=[]
# stat["fsky"]=[]
stat["lmax"]=[]
for k in data.keys():
    stat[k]=[]

for msk in masks.keys():
    for lmax in lmax_list:
        stat["mask"]=stat["mask"]+[msk]
        stat["lmax"]=stat["lmax"]+[lmax]
        for k in data.keys():
            CL=result[k][msk][lmax]["CL"]
            NL=result[k][msk][lmax]["NL"]
            fsky=result[k][msk][lmax]["fsky"]
            try:
                u95=calc_u95(CL,NL,fsky,Lmax)
                stat[k]=stat[k] + [u95]
            except:
                print("Failed : ",msk,lmax,k)
                stat[k]=stat[k] + [-1.]

# %%
birestat=pd.DataFrame(stat)
birestat.set_index(["mask","lmax"],inplace=True)
for col in birestat.columns:
    birestat[col]=birestat[col].apply(lambda x: '%.2E' % x)
# birestat.index.format(name="fsky",formatter=lambda x: '%.2f' % x)
birestat=birestat.style.set_caption(r"95% upper bounds on $A_{\rm CB}$ from Planck")
birestat=birestat.background_gradient()
filename=figpath + "bire_stat.jpeg"
dfi.export(birestat,filename,chrome_path=None)

# %%
birestat
# Out:
# <style  type="text/css" >
# </style><table id="T_271dd_" ><caption>95% upper bounds on $A_{\rm CB}$ from Planck</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SMICA</th>        <th class="col_heading level0 col1" >143 GHz</th>    </tr>    <tr>        <th class="index_name level0" >mask</th>        <th class="index_name level1" >lmax</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_271dd_level0_row0" class="row_heading level0 row0" rowspan="3">mask78</th>
#                         <th id="T_271dd_level1_row0" class="row_heading level1 row0" >768</th>
#                         <td id="T_271dd_row0_col0" class="data row0 col0" >4.19E-05</td>
#                         <td id="T_271dd_row0_col1" class="data row0 col1" >1.32E-04</td>
#             </tr>
#             <tr>
# ...

# %%
CL=result["SMICA"]["mask78"][1024]["CL"]
NL=result["SMICA"]["mask78"][1024]["NL"]
fsky=result["SMICA"]["mask78"][1024]["fsky"]

calc_u95(CL,NL,fsky,Lmax,Arng=[-5,-3],sampling=500)
# Out:
# array(4.19123262e-05)

# %%
calc_u95(CL,NL,fsky,Lmax,Arng=[-6,-3],sampling=500)
# Out:
# array(4.18769604e-05)
